# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
X1 = np.linspace(0,100,11)
y1 = np.zeros(11)

# %%
plt.plot(X1,y1)

# %%
# calculate the upper point of the triangle.

# %%
s = (3**0.5)*100/2

# %%
s
# Out:
# 86.60254037844386

# %%
x2 = np.linspace(0,50,5)
y2 = np.linspace(0,s,5)

# %%
plt.plot(x2,y2)

# %%
plt.plot(X1,y1)
plt.plot(x2,y2)

# %%
x3 = np.linspace(100,50,5)
y3 = np.linspace(0,s,5)

# %%
plt.plot(X1,y1,lw = 2)
plt.plot(x2,y2, lw = 2)
plt.plot(x3,y3,lw = 2)

# %%
x4 = [0,50,100]
y4 = [0,s,0]

# %%
plt.scatter(x4,y4)

# %%
plt.plot(X1,y1,lw = 2)
plt.plot(x2,y2, lw = 2)
plt.plot(x3,y3,lw = 2)
plt.scatter(50,s,s = 110,color = 'blue',label = 'Quartz')
plt.scatter(0,0,s = 110,color = 'green',label = 'Feldspar')
plt.scatter(100,0,s = 110,color = 'orange', label = 'Rock fragments')
plt.legend()

# %%
a = [20,60,40,70,60,80,80,90]
b = [0,80,0,60,0,40,0,20]

# %%
plt.plot(a,b)

# %%
plt.figure(figsize = (12,10))

plt.plot(X1,y1,lw = 2)
plt.plot(x2,y2, lw = 2)
plt.plot(x3,y3,lw = 2)

plt.scatter(50,s,s = 110,color = 'blue',label = 'Quartz')
plt.scatter(0,0,s = 110,color = 'green',label = 'Feldspar')
plt.scatter(100,0,s = 110,color = 'orange', label = 'Rock fragments')

plt.plot([20,60],[0,0.8*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([40,70],[0,0.6*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([60,80],[0,0.4*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([80,90],[0,0.2*s],linestyle = '--',color = 'black',alpha = 0.4)

plt.plot([10,90],[0.2*s,0.2*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([20,80],[0.4*s,0.4*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([30,70],[0.6*s,0.6*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([40,60],[0.8*s,0.8*s],linestyle = '--',color = 'black',alpha = 0.4)

plt.plot([20,10],[0,0.2*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([40,20],[0,0.4*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([60,30],[0,0.6*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([80,40],[0,0.8*s],linestyle = '--',color = 'black',alpha = 0.4)

plt.xticks([])
plt.yticks([])

plt.annotate('Quartz', (50,s), size = 15)
plt.annotate('Feldspar', (0,0), size = 15)
plt.annotate('Rock fragments', (100,0), size = 15)
plt.title('Ternary Diagram',color = 'darkblue', size = 15)
# Out:
# Text(0.5, 1.0, 'Ternary Diagram')

# %%
# data pointa
e = [50,52.63,52.36,27.84]
f = [33.33,52.63,78.53,20.62]

g = [84.69,76.60,71,88.6]
h = [10,14,18,8]

# %%
plt.figure(figsize = (12,10))

plt.plot(X1,y1,lw = 2)
plt.plot(x2,y2, lw = 2)
plt.plot(x3,y3,lw = 2)

plt.scatter(50,s,s = 110,color = 'blue',label = 'Quartz')
plt.scatter(0,0,s = 110,color = 'green',label = 'Feldspar')
plt.scatter(100,0,s = 110,color = 'orange', label = 'Rock fragments')

plt.plot([20,60],[0,0.8*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([40,70],[0,0.6*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([60,80],[0,0.4*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([80,90],[0,0.2*s],linestyle = '--',color = 'black',alpha = 0.4)

plt.plot([10,90],[0.2*s,0.2*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([20,80],[0.4*s,0.4*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([30,70],[0.6*s,0.6*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([40,60],[0.8*s,0.8*s],linestyle = '--',color = 'black',alpha = 0.4)

plt.plot([20,10],[0,0.2*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([40,20],[0,0.4*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([60,30],[0,0.6*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([80,40],[0,0.8*s],linestyle = '--',color = 'black',alpha = 0.4)


plt.scatter(e,f, marker = '^', s = 80, color = 'green')
plt.scatter(g,h, marker = '^', s = 80, color = 'red')
plt.xticks([])
plt.yticks([])

plt.annotate('Quartz', (50,s), size = 15)
plt.annotate('Feldspar', (0,0), size = 15, textcoords='axes fraction')
plt.annotate('Rock fragments', (100,0), size = 15)
plt.title('Ternary Diagram',color = 'darkblue', size = 15)
# Out:
# Text(0.5, 1.0, 'Ternary Diagram')

# %%
plt.figure(figsize = (16,14))
plt.style.use('default')
plt.plot(X1,y1,lw = 2)
plt.plot(x2,y2, lw = 2)
plt.plot(x3,y3,lw = 2)

plt.scatter(50,s,s = 110,color = 'blue',label = 'Quartz')
plt.scatter(0,0,s = 110,color = 'green',label = 'Feldspar')
plt.scatter(100,0,s = 110,color = 'orange', label = 'Rock fragments')

plt.plot([20,60],[0,0.8*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([40,70],[0,0.6*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([60,80],[0,0.4*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([80,90],[0,0.2*s],linestyle = '--',color = 'black',alpha = 0.4)

plt.plot([10,90],[0.2*s,0.2*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([20,80],[0.4*s,0.4*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([30,70],[0.6*s,0.6*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([40,60],[0.8*s,0.8*s],linestyle = '--',color = 'black',alpha = 0.4)

plt.plot([20,10],[0,0.2*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([40,20],[0,0.4*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([60,30],[0,0.6*s],linestyle = '--',color = 'black',alpha = 0.4)
plt.plot([80,40],[0,0.8*s],linestyle = '--',color = 'black',alpha = 0.4)

plt.plot([47.5,52.5],[0.95*s,0.95*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([37.5,62.5],[0.75*s,0.75*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([50,50],[0,0.95*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([25,(37.5+50)/2],[0,0.75*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([75,(62.5+50)/2],[0,0.75*s],linestyle = 'dashdot',color = 'black',lw = 1.6)

plt.xticks([])
plt.yticks([])

plt.annotate('Quartz', (50,s), size = 15)
plt.annotate('Arkose', (22,30), size = 15)
plt.annotate('Subarkose', (42,0.83*s), size = 12)
plt.annotate('Lithic_Arkose', (35,30), size = 15)
plt.annotate('Feldspathic Litharenite', (50,30), size = 12)
plt.annotate('Litharenite', (70,30), size = 15)
plt.annotate('Sublitharenit', (51,0.83*s), size = 12)
plt.annotate('Quartzarenite', (46,0.97*s), size = 12)


plt.annotate('Feldspar', (0,0.02), size = 15, textcoords='axes fraction')
plt.annotate('Rock fragments', (100,0), size = 15)
plt.title('Ternary Diagram',color = 'darkblue', size = 15)
# Out:
# Text(0.5, 1.0, 'Ternary Diagram')

# %%
plt.figure(figsize = (16,14))

plt.plot(X1,y1,lw = 2)
plt.plot(x2,y2, lw = 2)
plt.plot(x3,y3,lw = 2)

plt.scatter(50,s,s = 110,color = 'blue',label = 'Quartz')
plt.scatter(0,0,s = 110,color = 'green',label = 'Feldspar')
plt.scatter(100,0,s = 110,color = 'orange', label = 'Rock fragments')

plt.plot([20,60],[0,0.8*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([40,70],[0,0.6*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([60,80],[0,0.4*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([80,90],[0,0.2*s],linestyle = '--',color = 'black',alpha = 0.3)

plt.plot([10,90],[0.2*s,0.2*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([20,80],[0.4*s,0.4*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([30,70],[0.6*s,0.6*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([40,60],[0.8*s,0.8*s],linestyle = '--',color = 'black',alpha = 0.3)

plt.plot([20,10],[0,0.2*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([40,20],[0,0.4*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([60,30],[0,0.6*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([80,40],[0,0.8*s],linestyle = '--',color = 'black',alpha = 0.3)

plt.plot([47.5,52.5],[0.95*s,0.95*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([37.5,62.5],[0.75*s,0.75*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([50,50],[0,0.95*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([25,(37.5+50)/2],[0,0.75*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([75,(62.5+50)/2],[0,0.75*s],linestyle = 'dashdot',color = 'black',lw = 1.6)

plt.xticks([])
plt.yticks([])

plt.annotate('Quartz', (50,s), size = 15)
plt.annotate('Arkose', (22,30), size = 15)
plt.annotate('Subarkose', (42,0.83*s), size = 12)
plt.annotate('Lithic_Arkose', (35,30), size = 15)
plt.annotate('Feldspathic Litharenite', (50,30), size = 14)
plt.annotate('Litharenite', (70,30), size = 15)
plt.annotate('Sublitharenit', (51,0.83*s), size = 12)
plt.annotate('Quartzarenite', (46,0.97*s), size = 12)


plt.annotate('Feldspar', (0,0.02), size = 15, textcoords='axes fraction')
plt.annotate('Rock fragments', (100,0), size = 15)
plt.title('Ternary Diagram',color = 'darkblue', size = 15)

plt.scatter(e,f, marker = '^', s = 100, color = 'green')
plt.scatter(g,h, marker = '^', s = 100, color = 'red')

# %%
import pandas as pd

# %%
df = pd.read_excel('C:/Users/sahil/OneDrive/Desktop/EDVANTAGE/DATA/QFR.xlsx')

# %%
df.head()
# Out:
#        Q      F      R
# 0  78.16  13.95   7.89
# 1  87.85   5.61   6.54
# 2  82.74   5.58  11.68
# 3  75.12  15.52   9.36
# 4  82.17   8.53   9.30

# %%
df['X'] = df['R']+df['Q']/2

# %%
df['Y'] = df['Q']*s/100

# %%
df
# Out:
#         Q      F      R       X          Y
# 0   78.16  13.95   7.89  46.970  67.688546
# 1   87.85   5.61   6.54  50.465  76.080332
# 2   82.74   5.58  11.68  53.050  71.654942
# 3   75.12  15.52   9.36  46.920  65.055828
# 4   82.17   8.53   9.30  50.385  71.161307
# 5   80.99  12.35   6.67  47.165  70.139397
# 6   78.87  13.27   7.86  47.295  68.303424
# 7   76.36  14.95   8.70  46.880  66.129700
# 8   78.68   8.96  12.37  51.710  68.138879
# 9   80.00   8.38  11.62  51.620  69.282032
# 10  81.72  10.97   7.31  48.170  70.771596
# 11  80.60  12.57   6.83  47.130  69.801648
# 12  89.72  10.28   0.00  44.860  77.699799
# 13  85.34  10.10   4.56  47.230  73.906608
# 14  89.33  10.67   0.00  44.665  77.362049
# 15  82.93  10.40   6.67  48.135  71.819487

# %%
df1 = df[df['X']<50]

# %%
df2 = df[df['X']>=50]

# %%
plt.figure(figsize = (16,14))

plt.plot(X1,y1,lw = 2)
plt.plot(x2,y2, lw = 2)
plt.plot(x3,y3,lw = 2)

plt.scatter(50,s,s = 110,color = 'blue')
plt.scatter(0,0,s = 110,color = 'green')
plt.scatter(100,0,s = 110,color = 'orange')

plt.plot([20,60],[0,0.8*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([40,70],[0,0.6*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([60,80],[0,0.4*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([80,90],[0,0.2*s],linestyle = '--',color = 'black',alpha = 0.3)

plt.plot([10,90],[0.2*s,0.2*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([20,80],[0.4*s,0.4*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([30,70],[0.6*s,0.6*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([40,60],[0.8*s,0.8*s],linestyle = '--',color = 'black',alpha = 0.3)

plt.plot([20,10],[0,0.2*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([40,20],[0,0.4*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([60,30],[0,0.6*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([80,40],[0,0.8*s],linestyle = '--',color = 'black',alpha = 0.3)

plt.plot([47.5,52.5],[0.95*s,0.95*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([37.5,62.5],[0.75*s,0.75*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([50,50],[0,0.95*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([25,(37.5+50)/2],[0,0.75*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([75,(62.5+50)/2],[0,0.75*s],linestyle = 'dashdot',color = 'black',lw = 1.6)

plt.xticks([])
plt.yticks([])

plt.annotate('Quartz', (50,s), size = 15)
plt.annotate('Arkose', (22,30), size = 15)
plt.annotate('Subarkose', (42,0.83*s), size = 12)
plt.annotate('Lithic_Arkose', (35,30), size = 15)
plt.annotate('Feldspathic Litharenite', (50,30), size = 14)
plt.annotate('Litharenite', (70,30), size = 15)
plt.annotate('Sublitharenit', (51,0.83*s), size = 12)
plt.annotate('Quartzarenite', (46,0.97*s), size = 12)

plt.annotate('Feldspar', (0,0.02), size = 15, textcoords='axes fraction')
plt.annotate('Rock fragments', (100,0), size = 15)
plt.title('Ternary Diagram',color = 'darkblue', size = 18)

plt.scatter(g,h, marker = '^', s = 80, color = 'red', label = 'Litharenite')
plt.scatter(df1['X'],df1['Y'],marker = '^',s = 80, color = 'purple',label = 'Subarkose')
plt.scatter(df2['X'],df2['Y'],marker = '^',s = 80, color = 'green',label  = 'Sublitharenit')

plt.legend(fontsize=20)
plt.legend(fontsize="x-large")

# %%
plt.figure(figsize = (16,14))
plt.style.use('seaborn')
plt.plot(X1,y1,lw = 2)
plt.plot(x2,y2, lw = 2)
plt.plot(x3,y3,lw = 2)

plt.scatter(50,s,s = 110,color = 'blue')
plt.scatter(0,0,s = 110,color = 'green')
plt.scatter(100,0,s = 110,color = 'orange')

plt.plot([20,60],[0,0.8*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([40,70],[0,0.6*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([60,80],[0,0.4*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([80,90],[0,0.2*s],linestyle = '--',color = 'black',alpha = 0.3)

plt.plot([10,90],[0.2*s,0.2*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([20,80],[0.4*s,0.4*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([30,70],[0.6*s,0.6*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([40,60],[0.8*s,0.8*s],linestyle = '--',color = 'black',alpha = 0.3)

plt.plot([20,10],[0,0.2*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([40,20],[0,0.4*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([60,30],[0,0.6*s],linestyle = '--',color = 'black',alpha = 0.3)
plt.plot([80,40],[0,0.8*s],linestyle = '--',color = 'black',alpha = 0.3)

plt.plot([47.5,52.5],[0.95*s,0.95*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([37.5,62.5],[0.75*s,0.75*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([50,50],[0,0.95*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([25,(37.5+50)/2],[0,0.75*s],linestyle = 'dashdot',color = 'black',lw = 1.6)
plt.plot([75,(62.5+50)/2],[0,0.75*s],linestyle = 'dashdot',color = 'black',lw = 1.6)

plt.xticks([])
plt.yticks([])

plt.annotate('Quartz', (50,s), size = 15)
plt.annotate('Arkose', (22,30), size = 15)
plt.annotate('Subarkose', (42,0.83*s), size = 12)
plt.annotate('Lithic_Arkose', (35,30), size = 15)
plt.annotate('Feldspathic Litharenite', (50,30), size = 14)
plt.annotate('Litharenite', (70,30), size = 15)
plt.annotate('Sublitharenit', (51,0.83*s), size = 12)
plt.annotate('Quartzarenite', (46,0.97*s), size = 12)

plt.annotate('Feldspar', (0,0.02), size = 15, textcoords='axes fraction')
plt.annotate('Rock fragments', (100,0), size = 15)
plt.title('Ternary Diagram',color = 'darkblue', size = 18)

plt.scatter(g,h, marker = '^', s = 80, color = 'red', label = 'Litharenite')
plt.scatter(df1['X'],df1['Y'],marker = '^',s = 80, color = 'purple',label = 'Subarkose')
plt.scatter(df2['X'],df2['Y'],marker = '^',s = 80, color = 'green',label  = 'Sublitharenit')

plt.legend(fontsize=20)
plt.legend(fontsize="x-large")
