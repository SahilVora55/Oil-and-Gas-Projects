# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
xc,yc = 0,0

# %%
plt.scatter([xc,xc+5,xc-5,xc+5,xc-5],[yc,yc+5,yc-5,yc-5,yc+5])

# %%
5*(2**0.5)
# Out:
# 7.0710678118654755

# %%
plt.figure(figsize=(6,6))
plt.scatter([xc,xc+5,xc-5,xc+5,xc-5,xc+5*(2**0.5),xc-5*(2**0.5),xc,xc],[yc,yc+5,yc-5,yc-5,yc+5,yc,yc,yc+5*(2**0.5),yc-5*(2**0.5)])

# %%
plt.figure(figsize=(6,6))

plt.plot([xc+5,xc+5*(2**0.5),xc+5,xc,xc-5,xc-5*(2**0.5),xc-5,xc,xc+5],[yc+5,yc,yc-5,yc-5*(2**0.5),yc-5,yc,yc+5,yc+5*(2**0.5),yc+5]);

# %%
# equation of circle :   x^2 + y^2 = r^2

# %%
r = 5
x = np.linspace(-5,5,110)

# %%
y = (r**2 - x**2)**0.5

# %%
y
# Out:
# array([0.        , 0.95342246, 1.34208613, 1.63601417, 1.88017445,
#        2.092065  , 2.28069778, 2.45144756, 2.60782943, 2.75229358,
#        2.88662986, 3.01219361, 3.13004075, 3.24101316, 3.34579496,
#        3.44495107, 3.53895441, 3.62820549, 3.71304704, 3.79377489,
#        3.87064644, 3.9438872 , 4.01369594, 4.0802488 , 4.14370268,
#        4.20419789, 4.26186042, 4.3168038 , 4.36913061, 4.41893379,
#        4.46629778, 4.5112994 , 4.55400868, 4.59448955, 4.63280043,
#        4.66899473, 4.70312133, 4.73522492, 4.76534639, 4.79352311,
#        4.81978919, 4.8441757 , 4.8667109 , 4.8874204 , 4.90632732,
#        4.92345243, 4.93881425, 4.9524292 , 4.96431165, 4.97447402,
#        4.98292683, 4.98967877, 4.99473673, 4.99810586, 4.99978958,
#        4.99978958, 4.99810586, 4.99473673, 4.98967877, 4.98292683,
#        4.97447402, 4.96431165, 4.9524292 , 4.93881425, 4.92345243,
#        4.90632732, 4.8874204 , 4.8667109 , 4.8441757 , 4.81978919,
# ...

# %%
plt.plot(x,y)

# %%
y1 = -(r**2 - x**2)**0.5

# %%
plt.figure(figsize=(6,6))
plt.plot(x,y)
plt.plot(x,y1)

# %%
plt.figure(figsize=(6,6))
plt.plot(x,y,color = 'blue')
plt.plot(x,y1,color = 'blue')

# %%
plt.figure(figsize=(6,6))
plt.scatter(x,y,color = 'blue')
plt.scatter(x,y1,color = 'blue')

# %%
parimity = 2*(22/7)*r

# %%
parimity
# Out:
# 31.428571428571427

# %%
xc,yc = 0,0

# %%
x_p = np.linspace(5,-5,7)

# %%
y_p1 = (r**2 - x_p**2)**0.5

# %%
y_p1
# Out:
# array([0.        , 3.72677996, 4.71404521, 5.        , 4.71404521,
#        3.72677996, 0.        ])

# %%
plt.figure(figsize=(6,6))
plt.plot(x,y,color = 'blue')
plt.plot(x,y1,color = 'blue')
plt.grid()

# %%
x = np.linspace(-5,5,100)
a = 5
b = 2
# x^2/a^2 + y^2/b^2 = 1
# x2*b2 + y2*a2 = a2*b2
y1 = (((a**2)*(b**2)-(x**2)*(b**2))/(a**2))**0.5
y2 = -(((a**2)*(b**2)-(x**2)*(b**2))/(a**2))**0.5

# %%
plt.figure(figsize = (6,10))
plt.scatter(x,y1)
plt.scatter(x,y2)
plt.xlim(-7,7)
plt.ylim(-4,15)
# Out:
# (-4.0, 15.0)

# %%
x = np.linspace(-5,5,100)
a = 5
b = 2
# x^2/a^2 + y^2/b^2 = 1
# x2*b2 + y2*a2 = a2*b2
y3 = (((a**2)*(b**2)-(x**2)*(b**2))/(a**2))**0.5 + 10
y4 = -(((a**2)*(b**2)-(x**2)*(b**2))/(a**2))**0.5 + 10

# %%
plt.figure(figsize = (6,10))
plt.scatter(x,y1)
plt.scatter(x,y2)
plt.scatter(x,y3)
plt.scatter(x,y4)

plt.xlim(-7,7)
plt.ylim(-4,15)
# Out:
# (-4.0, 15.0)

# %%
plt.figure(figsize = (6,10))
plt.scatter(x,y1)
plt.scatter(x,y2)
plt.scatter(x,y3)
plt.scatter(x,y4)
plt.scatter(np.repeat(-5,100),np.linspace(0,10,100))
plt.scatter(np.repeat(5,100),np.linspace(0,10,100))
plt.xlim(-7,7)
plt.ylim(-4,15)
# Out:
# (-4.0, 15.0)

# %%
plt.figure(figsize = (6,10))
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)
plt.plot(np.repeat(-5,100),np.linspace(0,10,100))
plt.plot(np.repeat(5,100),np.linspace(0,10,100))
plt.xlim(-7,7)
plt.ylim(-4,15)
# Out:
# (-4.0, 15.0)

# %%
x_well = np.linspace(-1,1,100)
a1 = 1
b1= 0.33
# x^2/a^2 + y^2/b^2 = 1
# x2*b2 + y2*a2 = a2*b2
y1_well = (((a1**2)*(b1**2)-(x_well**2)*(b1**2))/(a1**2))**0.5
y2_well = -(((a1**2)*(b1**2)-(x_well**2)*(b1**2))/(a1**2))**0.5
y3_well = (((a1**2)*(b1**2)-(x_well**2)*(b1**2))/(a1**2))**0.5 + 13
y4_well = -(((a1**2)*(b1**2)-(x_well**2)*(b1**2))/(a1**2))**0.5 + 13

# %%
plt.figure(figsize = (6,10))
plt.scatter(x_well,y1_well)
plt.scatter(x_well,y2_well)
plt.scatter(x_well,y3_well)
plt.scatter(x_well,y4_well)
plt.scatter(np.repeat(-1,100),np.linspace(0,13,100))
plt.scatter(np.repeat(1,100),np.linspace(0,13,100))
plt.xlim(-7,7)
plt.ylim(-4,15)
# Out:
# (-4.0, 15.0)

# %%
plt.figure(figsize = (12,10))
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)
plt.plot(np.repeat(-5,100),np.linspace(0,10,100))
plt.plot(np.repeat(5,100),np.linspace(0,10,100))
plt.scatter(x_well,y1_well)
plt.scatter(x_well,y2_well)
plt.scatter(x_well,y3_well)
plt.scatter(x_well,y4_well)
plt.scatter(np.repeat(-1,100),np.linspace(0,13,100))
plt.scatter(np.repeat(1,100),np.linspace(0,13,100))
plt.xlim(-7,7)
plt.ylim(-4,15)
# Out:
# (-4.0, 15.0)

# %%
plt.figure(figsize = (12,10))
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)
plt.plot(np.repeat(-5,100),np.linspace(0,10,100))
plt.plot(np.repeat(5,100),np.linspace(0,10,100))
plt.scatter(x_well,y1_well)
plt.scatter(x_well,y2_well)
plt.scatter(x_well,y3_well)
plt.scatter(x_well,y4_well)
plt.scatter(np.repeat(-1,100),np.linspace(0,13,100))
plt.scatter(np.repeat(1,100),np.linspace(0,13,100))
plt.plot([0,0],[-3,15],linestyle='--')
plt.xlim(-7,7)
plt.ylim(-4,15)
# Out:
# (-4.0, 15.0)

# %%
plt.figure(figsize = (12,10))
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)

plt.plot(np.repeat(-5,100),np.linspace(0,10,100))
plt.plot(np.repeat(5,100),np.linspace(0,10,100))

plt.scatter(x_well,y1_well)
plt.scatter(x_well,y2_well)
plt.scatter(x_well,y3_well)
plt.scatter(x_well,y4_well)

plt.scatter(np.repeat(-1,100),np.linspace(0,13,100))
plt.scatter(np.repeat(1,100),np.linspace(0,13,100))

plt.plot([0,0],[-3,15],linestyle='--')

plt.xlim(-7,7)
plt.ylim(-4,15)

plt.plot(x,y1+3,linestyle = 'dotted')
plt.plot(x,y2+3,linestyle = 'dotted')

plt.plot(x,y1+7.5,linestyle = 'dotted')
plt.plot(x,y2+7.5,linestyle = 'dotted')

# %%
plt.figure(figsize = (12,10))
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)

plt.plot(np.repeat(-5,100),np.linspace(0,10,100))
plt.plot(np.repeat(5,100),np.linspace(0,10,100))

plt.scatter(x_well,y1_well)
plt.scatter(x_well,y2_well)
plt.scatter(x_well,y3_well)
plt.scatter(x_well,y4_well)

plt.scatter(np.repeat(-1,100),np.linspace(0,13,100))
plt.scatter(np.repeat(1,100),np.linspace(0,13,100))

plt.plot([0,0],[-3,15],linestyle='--')

plt.xlim(-7,7)
plt.ylim(-4,15)

plt.plot(x,y1+3,linestyle = 'dotted')
plt.plot(x,y2+3,linestyle = 'dotted')

plt.plot(x,y1+7.5,linestyle = 'dotted')
plt.plot(x,y2+7.5,linestyle = 'dotted')

plt.fill(x,y1,'skyblue',alpha = 0.3)
plt.fill(x,y2,'skyblue',alpha = 0.3)

plt.fill(x,y1+3,'black',alpha = 0.3)
plt.fill(x,y2+3,'black',alpha = 0.3)

plt.fill(x,y1+7.5,'orange',alpha = 0.2)
plt.fill(x,y2+7.5,'orange',alpha = 0.2)

plt.fill(x,y3,'orange',alpha = 0.2)
plt.fill(x,y4,'orange',alpha = 0.2)

plt.fill_between(x,y1,y2+3,color = 'skyblue',alpha=0.3)
plt.fill_between(x,y2+7.5,y1+3,color = 'black',alpha=0.3)
plt.fill_between(x,y4,y1+7.5,color = 'orange',alpha=0.2)

plt.fill(x_well,y2_well,x_well,y1_well,'green')

# %%
plt.figure(figsize = (12,10))
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)

plt.plot(np.repeat(-5,100),np.linspace(0,10,100))
plt.plot(np.repeat(5,100),np.linspace(0,10,100))

plt.scatter(x_well,y1_well)
plt.scatter(x_well,y2_well)
plt.scatter(x_well,y3_well)
plt.scatter(x_well,y4_well)

plt.scatter(np.repeat(-1,100),np.linspace(0,13,100))
plt.scatter(np.repeat(1,100),np.linspace(0,13,100))

plt.plot([0,0],[-3,15],linestyle='--')

plt.xlim(-7,7)
plt.ylim(-4,15)

plt.plot(x,y1+3,linestyle = 'dotted')
plt.plot(x,y2+3,linestyle = 'dotted')

plt.plot(x,y1+7.5,linestyle = 'dotted')
plt.plot(x,y2+7.5,linestyle = 'dotted')

plt.fill(x,y1,'skyblue',alpha = 0.3)
plt.fill(x,y2,'skyblue',alpha = 0.3)

plt.fill(x,y1+3,'black',alpha = 0.3)
plt.fill(x,y2+3,'black',alpha = 0.3)

plt.fill(x,y1+7.5,'orange',alpha = 0.2)
plt.fill(x,y2+7.5,'orange',alpha = 0.2)

plt.fill(x,y3,'orange',alpha = 0.2)
plt.fill(x,y4,'orange',alpha = 0.2)

plt.fill_between(x,y1,y2+3,color = 'skyblue',alpha=0.3)
plt.fill_between(x,y2+7.5,y1+3,color = 'black',alpha=0.3)
plt.fill_between(x,y4,y1+7.5,color = 'orange',alpha=0.2)

plt.annotate('Gas Zone',(-3.5,7),size=16,color = 'green')
plt.annotate('Oil Zone',(-3.5,4),size=16,color = 'green')
plt.annotate('Water Zone',(-3.5,0),size=16,color = 'green')

plt.plot([0,5],[0,0],linestyle='--',color='red')
plt.annotate('re',(3,-0.5),size=14,color = 'red')
plt.plot([0,1],[0,0],linestyle='--',color='blue')
plt.annotate('rw',(0.4,-0.5),size=14,color = 'blue')
plt.plot(np.repeat(5.5,100),np.linspace(0,10,100),linestyle='--',color='blue')
plt.annotate('h',(5.7,5),size=14,color = 'blue')
# Out:
# Text(5.7, 5, 'h')
