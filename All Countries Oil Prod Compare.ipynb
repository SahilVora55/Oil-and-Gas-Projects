# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Oil_Prod = pd.read_excel('T35.xlsx', index_col = 0).T

# %%
Oil_Prod.head()
# Out:
# Year  OECD Americas   Canada   Chile   Mexico  United States  OECD Europe  \
# 1960       7885.831  563.836  21.605  265.090         7035.3      318.798
# 1961       8155.930  658.770  27.716  286.544         7182.9      343.504
# 1962       8395.308  728.229  34.918  300.161         7332.0      366.264
# 1963       8657.895  768.402  39.501  308.292         7541.7      392.596
# 1964       8781.328  816.849  40.810  309.369         7614.3      425.004
#
# Year  Denmark  Norway  United Kingdom   Others  ...  Kuwait1  Libya  Nigeria  \
# 1960      0.0     0.0           1.761  317.037  ...   1691.8    0.0     17.4
# 1961      0.0     0.0           2.279  341.225  ...   1735.0   18.2     46.0
# 1962      0.0     0.0           2.383  363.881  ...   1957.8  182.3     67.5
# 1963      0.0     0.0           2.590  390.006  ...   2096.3  441.8     76.5
# 1964      0.0     0.0           2.798  422.206  ...   2301.0  862.4    120.2
#
# ...

# %%
plt.bar(Oil_Prod.index,Oil_Prod['India'],width = 0.7,color = 'g')
# Out:
# <BarContainer object of 61 artists>

# %%
plt.plot(Oil_Prod['India'])

# %%
plt.figure(figsize = (15,15))

plt.plot(Oil_Prod, label = Oil_Prod.columns)

plt.legend(loc = 'best')

plt.title('Oil_Production of Every Countries',size = 15, color = 'Blue')
# Out:
# Text(0.5, 1.0, 'Oil_Production of Every Countries')

# %%
columns = Oil_Prod.columns

# %%
scaled_Oil_Prod = Oil_Prod
for i in columns:
    scaled_Oil_Prod[i] = Oil_Prod[i]/Oil_Prod[i].max()

# %%
plt.figure(figsize=(8,4))
plt.plot(scaled_Oil_Prod['India'])
plt.plot(scaled_Oil_Prod['Total World '])
plt.figure(figsize=(8,4))
plt.plot(scaled_Oil_Prod['India'])
plt.plot(scaled_Oil_Prod['China'])
plt.figure(figsize=(8,4))
plt.plot(scaled_Oil_Prod['India'])
plt.plot(scaled_Oil_Prod['OECD Americas'])

# %%
scaled_Oil_Prod.columns
# Out:
# Index(['OECD Americas', 'Canada', 'Chile', 'Mexico', 'United States',
#        'OECD Europe', 'Denmark', 'Norway', 'United Kingdom', 'Others',
#        'OECD Asia and Pacific', 'Australia', 'Others', 'China', 'India',
#        'Other Asia', 'Brunei', 'Indonesia', 'Malaysia', 'Thailand', 'Vietnam',
#        'Others', 'Latin America', 'Argentina', 'Brazil', 'Colombia', 'Ecuador',
#        'Guyana', 'Others', 'Middle East ', 'Bahrain', 'Oman', 'Qatar',
#        'Syrian Arab Rep.', 'Yemen', 'Africa ', 'Cameroon', 'Chad', 'Egypt',
#        'Ghana', 'Sudans', 'Others', 'Russia', 'Other Eurasia', 'Azerbaijan',
#        'Kazakhstan', 'Others', 'Other Europe', 'Total Non OPEC', 'OPEC',
#        'Algeria', 'Angola', 'Congo', 'Equatorial Guinea', 'Gabon', 'IR Iran',
#        'Iraq', 'Kuwait1', 'Libya', 'Nigeria', 'Saudi Arabia1',
#        'United Arab Emirates', 'Venezuela', 'Total World ', 'of which',
#        'OPEC Share in %', 'OECD'],
#       dtype='object', name='Year')
